# %% [markdown]
# ## ***Initials***

# %%
import pandas as pd

# %% [markdown]
# ## ***Load the Data***

# %%
df = pd.read_csv("C:\\Users\\Giorgos\\Desktop\\HMMY\\10ο Εξάμηνο\\Διπλωματική\\5. Neighborhoods\\neighborhoods.csv")
print(len(df))
df.head()
# Out:
# 48
#                                                  WKT  fid  \
# 0  MULTIPOLYGON (((406692.718139543 4357521.85294...    1
# 1  MULTIPOLYGON (((396744.165394512 4351195.65810...    2
# 2  MULTIPOLYGON (((400839.361742302 4353031.79092...    3
# 3  MULTIPOLYGON (((406589.250339913 4357224.83344...    4
# 4  MULTIPOLYGON (((407619.510540358 4356306.42684...    5
#
#                      community           point_name         method  \
# 0  Δημοτική Κοινότητα Διμηνίου               Δημίνι      no points
# 1   Δημοτική Κοινότητα Σέσκλου  Χρυσή Ακτή Παναγίας  2-point split
# 2   Δημοτική Κοινότητα Σέσκλου               Σέσκλο  2-point split
# 3     Δημοτική Κοινότητα Βόλου      Άγιοι Ανάργυροι            NaN
# 4     Δημοτική Κοινότητα Βόλου          Αϊβαλιώτικα            NaN
#
#        full_id        osm_id osm_type          place             name  ...  \
# 0          NaN           NaN      NaN            NaN              NaN  ...
# ...

# %% [markdown]
# ## ***Clean the Data***

# %%
# Keep only the necessary columns
keep_cols = [
    'community', 'point_name',
    'centroid_x', 'centroid_y', 'area',
    'WKT'
]

# %%
cleaned_df = df[keep_cols].copy()
print(len(cleaned_df))
# Out:
# 48

# %%
cleaned_df.rename(columns={'community': 'Municipal Community', 'point_name': 'Name'}, inplace=True)

# %%
cleaned_df.head()
# Out:
#            Municipal Community                 Name  centroid_x  centroid_y  \
# 0  Δημοτική Κοινότητα Διμηνίου               Δημίνι   22.882945   39.349112
# 1   Δημοτική Κοινότητα Σέσκλου  Χρυσή Ακτή Παναγίας   22.836899   39.305430
# 2   Δημοτική Κοινότητα Σέσκλου               Σέσκλο   22.838168   39.353051
# 3     Δημοτική Κοινότητα Βόλου      Άγιοι Ανάργυροι   22.924059   39.366937
# 4     Δημοτική Κοινότητα Βόλου          Αϊβαλιώτικα   22.922660   39.343696
#
#         area                                                WKT
# 0  37.344776  MULTIPOLYGON (((406692.718139543 4357521.85294...
# 1   9.983032  MULTIPOLYGON (((396744.165394512 4351195.65810...
# 2  27.367312  MULTIPOLYGON (((400839.361742302 4353031.79092...
# 3   0.774436  MULTIPOLYGON (((406589.250339913 4357224.83344...
# 4   4.848904  MULTIPOLYGON (((407619.510540358 4356306.42684...

# %%
# Save to new file
cleaned_df.to_csv("neighborhoods_cleaned.csv", index=False)
