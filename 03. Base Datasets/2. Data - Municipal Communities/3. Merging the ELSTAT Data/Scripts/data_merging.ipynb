# %% [markdown]
# ## ***Initials***

# %%
import pandas as pd

# %% [markdown]
# ## ***Load the Data***

# %%
df1 = pd.read_csv("C:\\Users\\Giorgos\\Desktop\\HMMY\\10ο Εξάμηνο\\Διπλωματική\\3. Base Datasets\\2. Data - Municipal Communities\\1. Demographic Data\\Extracted CSV Files\\ELSTAT-demographic.csv")
df2 = pd.read_csv("C:\\Users\\Giorgos\\Desktop\\HMMY\\10ο Εξάμηνο\\Διπλωματική\\3. Base Datasets\\2. Data - Municipal Communities\\2. Economic Data\\Extracted CSV Files\\ELSTAT-economic.csv")

# %%
print(df1.shape)
df1.head()
# Out:
# (76, 32)
#              ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ        ΔΗΜΟΣ           ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ  \
# 0  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ     ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΒΟΛΟΥ
# 1  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ    ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΓΡΙΑΣ
# 2  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ    ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΓΡΙΑΣ
# 3  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ  ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΙΣΩΝΙΑΣ
# 4  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ  ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΙΣΩΝΙΑΣ
#
#             ΔΗΜΟΤΙΚΗ ΚΟΙΝΟΤΗΤΑ  Population   0-4   5-9  10-14  15-19  25-29  \
# 0     Δημοτική Κοινότητα Βόλου       85806  3204  3638   4315   5086   4174
# 1    Δημοτική Κοινότητα Αγριάς        4926   183   247    263    277    203
# 2  Δημοτική Κοινότητα Δρακείας         369    11    14     22     16     21
# 3  Δημοτική Κοινότητα Διμηνίου        2101   102    97    112    127    119
# 4   Δημοτική Κοινότητα Σέσκλου         899    36    51     72     40     47
#
# ...

# %%
print(df2.shape)
df2.head()
# Out:
# (76, 12)
#              ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ        ΔΗΜΟΣ           ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ  \
# 0  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ     ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΒΟΛΟΥ
# 1  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ    ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΓΡΙΑΣ
# 2  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ    ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΓΡΙΑΣ
# 3  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ  ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΙΣΩΝΙΑΣ
# 4  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ  ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΙΣΩΝΙΑΣ
#
#             ΔΗΜΟΤΙΚΗ ΚΟΙΝΟΤΗΤΑ  Σύνολο  Οικονομικά ενεργοί  Απασχολούμενοι  \
# 0     Δημοτική Κοινότητα Βόλου   85806               35938           30389
# 1    Δημοτική Κοινότητα Αγριάς    4926                1948            1642
# 2  Δημοτική Κοινότητα Δρακείας     369                 139             121
# 3  Δημοτική Κοινότητα Διμηνίου    2101                 909             706
# 4   Δημοτική Κοινότητα Σέσκλου     899                 345             302
#
# ...

# %% [markdown]
# ## ***Merge the Datasets***

# %%
common_cols = ['ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ', 'ΔΗΜΟΣ', 'ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ', 'ΔΗΜΟΤΙΚΗ ΚΟΙΝΟΤΗΤΑ']

# %%
merged_df = pd.merge(df1, df2, on=common_cols, how='inner')

# %%
print(merged_df.shape)
merged_df.head()
# Out:
# (76, 40)
#              ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ        ΔΗΜΟΣ           ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ  \
# 0  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ     ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΒΟΛΟΥ
# 1  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ    ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΓΡΙΑΣ
# 2  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ    ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΓΡΙΑΣ
# 3  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ  ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΙΣΩΝΙΑΣ
# 4  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ  ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΙΣΩΝΙΑΣ
#
#             ΔΗΜΟΤΙΚΗ ΚΟΙΝΟΤΗΤΑ  Population   0-4   5-9  10-14  15-19  25-29  \
# 0     Δημοτική Κοινότητα Βόλου       85806  3204  3638   4315   5086   4174
# 1    Δημοτική Κοινότητα Αγριάς        4926   183   247    263    277    203
# 2  Δημοτική Κοινότητα Δρακείας         369    11    14     22     16     21
# 3  Δημοτική Κοινότητα Διμηνίου        2101   102    97    112    127    119
# 4   Δημοτική Κοινότητα Σέσκλου         899    36    51     72     40     47
#
# ...

# %% [markdown]
# ## ***Save the Data***

# %%
merged_df.to_csv("C:\\Users\\Giorgos\\Desktop\\HMMY\\10ο Εξάμηνο\\Διπλωματική\\3. Base Datasets\\2. Data - Municipal Communities\\3. Merging the ELSTAT Data\\Extracted CSV Files\\ELSTAT-demographic-economic.csv", index=False)
