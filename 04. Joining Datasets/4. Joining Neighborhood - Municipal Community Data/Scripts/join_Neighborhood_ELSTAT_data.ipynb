# %% [markdown]
# ## ***Initials***

# %%
import pandas as pd

# %% [markdown]
# ## ***Load the Data***

# %%
neighborhood_df = pd.read_csv('C:\\Users\\Giorgos\\Desktop\\HMMY\\10ο Εξάμηνο\\Διπλωματική\\3. Base Datasets\\3. Data -  Smaller Spatial Units\\1. Neighborhoods\\Extracted CSV Files\\neighborhoods_enriched.csv')
neighborhood_df.drop(columns=['Neighborhood_Greek'], inplace=True)
print(neighborhood_df.shape)
print(neighborhood_df.columns)
neighborhood_df.head()
# Out:
# (48, 11)
# Index(['Municipal Community', 'Neighborhood', 'Centroid_x', 'Centroid_y',
#        'Neighborhood_Area_km2', 'Geometry', 'distance_to_volos_center_km',
#        'distance_to_volos_port_km', 'dist_to_main_road_km',
#        'dist_to_bus_stop_km', 'dist_to_university_km'],
#       dtype='object')
#               Municipal Community         Neighborhood  Centroid_x  \
# 0   Municipal Community of Dimini               Dimini   22.882945
# 1  Municipal Community of Sesklos  Xrisi Akti Panagias   22.836899
# 2  Municipal Community of Sesklos               Sesklo   22.838168
# 3    Municipal Community of Volos      Agioi Anargiroi   22.924059
# 4    Municipal Community of Volos          Aivaliotika   22.922660
#
#    Centroid_y  Neighborhood_Area_km2  \
# 0   39.349112              37.344776
# 1   39.305430               9.983032
# 2   39.353051              27.367312
# 3   39.366937               0.774436
# 4   39.343696               4.848904
#
#                                             Geometry  \
# 0  MULTIPOLYGON (((406692.718139543 4357521.85294...
# 1  MULTIPOLYGON (((396744.165394512 4351195.65810...
# 2  MULTIPOLYGON (((400839.361742302 4353031.79092...
# 3  MULTIPOLYGON (((406589.250339913 4357224.83344...
# 4  MULTIPOLYGON (((407619.510540358 4356306.42684...
#
#    distance_to_volos_center_km  distance_to_volos_port_km  \
# 0                     6.154015                   5.418577
# 1                    11.932475                  11.015584
# 2                     9.814666                   9.191001
# 3                     2.296184                   1.978856
# 4                     3.508166                   2.529372
#
#    dist_to_main_road_km  dist_to_bus_stop_km  dist_to_university_km
# 0              0.443434             1.569912               4.273031
# 1              2.299921             2.410375              10.100771
# 2              0.482308             4.965561               7.989610
# 3              0.058142             0.063879               0.866021
# 4              0.224486             0.246542               1.913456

# %%
municipal_community_df = pd.read_csv("C:\\Users\\Giorgos\\Desktop\\HMMY\\10ο Εξάμηνο\\Διπλωματική\\3. Base Datasets\\2. Data - Municipal Communities\\4. Exploratory Data Analysis\\Extracted CSV Files\\ELSTAT-demographic-economic.csv", index_col=0)
municipal_community_df.drop(columns=['ΔΗΜΟΤΙΚΗ ΚΟΙΝΟΤΗΤΑ ΕΛΛ'], inplace=True)
print(municipal_community_df.shape)
print(municipal_community_df.columns)
municipal_community_df.head()
# Out:
# (76, 21)
# Index(['ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ', 'ΔΗΜΟΣ', 'ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ',
#        'ΔΗΜΟΤΙΚΗ ΚΟΙΝΟΤΗΤΑ', 'Population', 'Άγαμοι_pct', 'Έγγαμοι_pct',
#        'Χήροι_pct', 'Διαζευγμένοι_pct', 'age_0_14_pct', 'age_15_64_pct',
#        'age_65_plus_pct', 'low_education_pct', 'medium_education_pct',
#        'high_education_pct', 'unemployment_rate',
#        'labor_force_participation_rate', 'primary_sector_pct',
#        'secondary_sector_pct', 'tertiary_sector_pct', 'Area_km2'],
#       dtype='object')
#              ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ        ΔΗΜΟΣ           ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ  \
# 0  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ     ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΒΟΛΟΥ
# 1  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ    ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΓΡΙΑΣ
# 2  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ    ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΓΡΙΑΣ
# 3  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ  ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΙΣΩΝΙΑΣ
# 4  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ  ΔΗΜΟΣ ΒΟΛΟΥ  ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΙΣΩΝΙΑΣ
#
#                ΔΗΜΟΤΙΚΗ ΚΟΙΝΟΤΗΤΑ  Population  Άγαμοι_pct  Έγγαμοι_pct  \
# 0    Municipal Community of Volos       85806      0.4032       0.4630
# 1    Municipal Community of Agria        4926      0.3577       0.5173
# 2  Municipal Community of Drakeia         369      0.3496       0.4580
# 3   Municipal Community of Dimini        2101      0.3889       0.5007
# 4  Municipal Community of Sesklos         899      0.3960       0.5184
#
#    Χήροι_pct  Διαζευγμένοι_pct  age_0_14_pct  ...  age_65_plus_pct  \
# 0     0.0809            0.0528        0.1300  ...           0.2221
# 1     0.0796            0.0461        0.1407  ...           0.2359
# 2     0.1382            0.0325        0.1274  ...           0.2873
# 3     0.0776            0.0343        0.1480  ...           0.2080
# 4     0.0645            0.0234        0.1769  ...           0.2147
#
#    low_education_pct  medium_education_pct  high_education_pct  \
# 0             0.3634                0.3663              0.2704
# 1             0.4670                0.3341              0.1987
# 2             0.6667                0.2493              0.0840
# 3             0.5437                0.3163              0.1395
# 4             0.6009                0.2812              0.1179
#
#    unemployment_rate  labor_force_participation_rate  primary_sector_pct  \
# 0             0.1545                          0.4188              0.0313
# 1             0.1555                          0.3955              0.0816
# 2             0.1439                          0.3767              0.4545
# 3             0.2211                          0.4327              0.1161
# 4             0.1304                          0.3838              0.1424
#
#    secondary_sector_pct  tertiary_sector_pct   Area_km2
# 0                0.1666               0.8022  26.790807
# 1                0.1864               0.7314   3.737347
# 2                0.0826               0.4628  21.683415
# 3                0.2365               0.6459  37.323451
# 4                0.3609               0.4967  37.329725
#
# [5 rows x 21 columns]

# %% [markdown]
# ## ***Merge: Neighborhoods with Municipal Communties***

# %%
# Perform the merge
community_df_renamed = municipal_community_df.rename(columns={'ΔΗΜΟΤΙΚΗ ΚΟΙΝΟΤΗΤΑ': 'Municipal Community'})

neighborhood_ELSTAT_df = pd.merge(
    neighborhood_df,
    community_df_renamed,
    on='Municipal Community',
    how='left'
)

print(neighborhood_ELSTAT_df.shape)
print(neighborhood_ELSTAT_df.columns)
neighborhood_ELSTAT_df.head()
# Out:
# (48, 31)
# Index(['Municipal Community', 'Neighborhood', 'Centroid_x', 'Centroid_y',
#        'Neighborhood_Area_km2', 'Geometry', 'distance_to_volos_center_km',
#        'distance_to_volos_port_km', 'dist_to_main_road_km',
#        'dist_to_bus_stop_km', 'dist_to_university_km', 'ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ',
#        'ΔΗΜΟΣ', 'ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ', 'Population', 'Άγαμοι_pct', 'Έγγαμοι_pct',
#        'Χήροι_pct', 'Διαζευγμένοι_pct', 'age_0_14_pct', 'age_15_64_pct',
#        'age_65_plus_pct', 'low_education_pct', 'medium_education_pct',
#        'high_education_pct', 'unemployment_rate',
#        'labor_force_participation_rate', 'primary_sector_pct',
#        'secondary_sector_pct', 'tertiary_sector_pct', 'Area_km2'],
#       dtype='object')
#               Municipal Community         Neighborhood  Centroid_x  \
# 0   Municipal Community of Dimini               Dimini   22.882945
# 1  Municipal Community of Sesklos  Xrisi Akti Panagias   22.836899
# 2  Municipal Community of Sesklos               Sesklo   22.838168
# 3    Municipal Community of Volos      Agioi Anargiroi   22.924059
# 4    Municipal Community of Volos          Aivaliotika   22.922660
#
#    Centroid_y  Neighborhood_Area_km2  \
# 0   39.349112              37.344776
# 1   39.305430               9.983032
# 2   39.353051              27.367312
# 3   39.366937               0.774436
# 4   39.343696               4.848904
#
#                                             Geometry  \
# 0  MULTIPOLYGON (((406692.718139543 4357521.85294...
# 1  MULTIPOLYGON (((396744.165394512 4351195.65810...
# 2  MULTIPOLYGON (((400839.361742302 4353031.79092...
# 3  MULTIPOLYGON (((406589.250339913 4357224.83344...
# 4  MULTIPOLYGON (((407619.510540358 4356306.42684...
#
#    distance_to_volos_center_km  distance_to_volos_port_km  \
# 0                     6.154015                   5.418577
# 1                    11.932475                  11.015584
# 2                     9.814666                   9.191001
# 3                     2.296184                   1.978856
# 4                     3.508166                   2.529372
#
#    dist_to_main_road_km  dist_to_bus_stop_km  ...  age_65_plus_pct  \
# 0              0.443434             1.569912  ...           0.2080
# 1              2.299921             2.410375  ...           0.2147
# 2              0.482308             4.965561  ...           0.2147
# 3              0.058142             0.063879  ...           0.2221
# 4              0.224486             0.246542  ...           0.2221
#
#   low_education_pct medium_education_pct high_education_pct  \
# 0            0.5437               0.3163             0.1395
# 1            0.6009               0.2812             0.1179
# 2            0.6009               0.2812             0.1179
# 3            0.3634               0.3663             0.2704
# 4            0.3634               0.3663             0.2704
#
#    unemployment_rate  labor_force_participation_rate  primary_sector_pct  \
# 0             0.2211                          0.4327              0.1161
# 1             0.1304                          0.3838              0.1424
# 2             0.1304                          0.3838              0.1424
# 3             0.1545                          0.4188              0.0313
# 4             0.1545                          0.4188              0.0313
#
#    secondary_sector_pct  tertiary_sector_pct   Area_km2
# 0                0.2365               0.6459  37.323451
# 1                0.3609               0.4967  37.329725
# 2                0.3609               0.4967  37.329725
# 3                0.1666               0.8022  26.790807
# 4                0.1666               0.8022  26.790807
#
# [5 rows x 31 columns]

# %% [markdown]
# ## ***Save the Data***

# %%
neighborhood_ELSTAT_df.to_csv("C:\\Users\\Giorgos\\Desktop\\HMMY\\10ο Εξάμηνο\\Διπλωματική\\4. Joining Datasets\\4. Joining Neighborhood - Municipal Community Data\\Extracted CSV Files\\neighborhood_ELSTAT.csv")
