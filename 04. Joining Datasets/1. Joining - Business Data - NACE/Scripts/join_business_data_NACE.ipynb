# %% [markdown]
# So far i have cleaned and merged the data, filling the missing values i could find and deleting the ones i could not or were invalid. Now i want to integrate the NACE column. I think i must first examine the 'Category' feature

# %% [markdown]
# ## ***Initials***

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## ***Load the Data***

# %%
df = pd.read_csv("C:\\Users\\Giorgos\\Desktop\\HMMY\\10ο Εξάμηνο\\Διπλωματική\\2. Base Datasets\\3. Merging - Business Data\\Extracted CSV Files\\business_data.csv")
print(len(df))
df.head()
# Out:
# 3906
#                              Name  \
# 0                       Άνθη-φυτά
# 1                Μέταλλο και ξύλο
# 2           Προφήτης Ηλίας Αλυκών
# 3  Frago Cargo (Φραγγοσ Νικολαοσ)
# 4       Αλφα Ωμεγα Express Market
#
#                                             Category   Latitude  Longitude  \
# 0                                       Flower Store  39.335293  22.923506
# 1                           Furniture and Home Store  39.339233  22.923969
# 2                                             Church  39.332305  22.926496
# 3  Shipping, Freight, and Material Transportation...  39.332756  22.929457
# 4                                      Grocery Store  39.332876  22.929374
#
#                  Address Country             City  Postal Code  Rating  \
# 0              6χλ.βολου  Greece  Βόλος Μαγνησίας        38334     NaN
# 1  Βόλου - Αθηνών 7ο χλμ  Greece  Βόλος Μαγνησίας        38334     NaN
# 2    Λεωφόρος Αθηνών 155  Greece  Βόλος Μαγνησίας        38334     NaN
# ...

# %% [markdown]
# ## ***Inspect the Feature: 'Category' - Create 'categories.csv'***

# %%
categories = df['Category'].dropna().unique()
print(len(categories))
print(sorted(categories))
# Out:
# 1239
# ...

# %% [markdown]
# Create the file that contains all the unique categories. They will be MANUALLY mapped to their corresponding NACE Code later

# %%
df['Category'].value_counts().to_csv("categories.csv")

# %% [markdown]
# ## ***Add the Features: 'NACE Code' / 'NACE Description (EN)'***

# %% [markdown]
# I ***manually*** performed the Category - NACE mapping in "categories.csv". I used a ***spatial join*** to add the columns "NACE Code" / "NACE Description (EN)", probably ***off-screen***.

# %% [markdown]
# I see 6 entries with missing values in these columns, but i will add them manually

# %%
df = pd.read_csv("C:\\Users\\Giorgos\\Desktop\\HMMY\\10ο Εξάμηνο\\Διπλωματική\\2. Base Datasets\\6. Joining - Business Data - NACE\\Extracted CSV Files\\business_data.csv")
print(len(df))
df.head()
# Out:
# 3906
#                              Name  \
# 0                       Άνθη-φυτά
# 1                Μέταλλο και ξύλο
# 2           Προφήτης Ηλίας Αλυκών
# 3  Frago Cargo (Φραγγοσ Νικολαοσ)
# 4       Αλφα Ωμεγα Express Market
#
#                                             Category   Latitude  Longitude  \
# 0                                       Flower Store  39.335293  22.923506
# 1                           Furniture and Home Store  39.339233  22.923969
# 2                                             Church  39.332305  22.926496
# 3  Shipping, Freight, and Material Transportation...  39.332756  22.929457
# 4                                      Grocery Store  39.332876  22.929374
#
#                  Address Country             City  Postal Code  Rating  \
# 0              6χλ.βολου  Greece  Βόλος Μαγνησίας        38334     NaN
# 1  Βόλου - Αθηνών 7ο χλμ  Greece  Βόλος Μαγνησίας        38334     NaN
# 2    Λεωφόρος Αθηνών 155  Greece  Βόλος Μαγνησίας        38334     NaN
# ...

# %%
no_NACE_df = df[df['NACE Code'].isna()]
print(len(no_NACE_df))
no_NACE_df.head(30)
# Out:
# 0
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Category, Latitude, Longitude, Address, Country, City, Postal Code, Rating, Reviews, Source, Description, NACE Code, NACE Description (EN)]
# Index: []
